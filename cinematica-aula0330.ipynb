# %% [markdown]
# <a href="https://colab.research.google.com/github/oliveiracidinho21-rgb/cnweb_2b2_a/blob/main/cinematica-aula0330.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fórmula da velocidade

# %%
def calculaAceleracao(deltaS, deltaT, deltaV):
  aceleracao = (deltaV / deltaT)
  return aceleracao
# Out:
#   File "/tmp/ipykernel_12834/2204093330.py", line 1
#     def calculaVelMedia(deltaS, deltaT)
#                                        ^
# SyntaxError: expected ':'

# %% [markdown]
# # Fórmula da aceleração
#
# ---

# %%
def calculaAceleracao(deltaV / deltaT);
  aceleracao = (deltaV / deltaT)
  return aceleracao

# %%
def calculaAceleracao(deltaV, deltaT);
  aceleracao = (deltaV / deltaT)
  return aceleracao

print("a =", calculaAceleracao(20, 10))

# %% [markdown]
# # Formula do movimento uniforme

# %%
def

# %% [markdown]
# # Função horaria de deslocamento

# %%
def funcaoHorariaDeslocamento(s0, v0, t, a);
  s = s0 + (v0 * t) + (a * t**2) / 2
  return S

# %%
print("s =", funcaoHorariaDeslocamento(10, 5, 2, 2))
